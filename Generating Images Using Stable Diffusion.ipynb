# %%
import time
import matplotlib.pyplot as plt
from diffusers import StableDiffusionPipeline
import torch

# %%
model_id = "runwayml/stable-diffusion-v1-5"
pipe = StableDiffusionPipeline.from_pretrained(model_id)
# Out:
# Fetching 19 files:   0%|          | 0/19 [00:00<?, ?it/s]
# `text_config_dict` is provided which will be used to initialize `CLIPTextConfig`. The value `text_config["id2label"]` will be overriden.

# %%
#fix seed
generator = torch.Generator("cpu").manual_seed(1024)

prompt = "sailing ship in storm by Rembrandt"
image = pipe(prompt, generator=generator, num_inference_steps=10, output_type="np").images
plt.imshow(image[0])
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]

# %%
#fix seed
generator = torch.Generator("cpu").manual_seed(1024)

prompt = "sailing ship in storm by Rembrandt"
image = pipe(prompt, generator=generator, num_inference_steps=10, output_type="np").images
plt.imshow(image[0])
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]

# %%
image.shape
# Out:
# (1, 512, 512, 3)

# %%
pipe = pipe.to("mps")

# Recommended if your computer has < 64 GB of RAM
pipe.enable_attention_slicing()

#fix seed
generator = torch.Generator("cpu").manual_seed(1024)

prompt = "sailing ship in storm by Rembrandt"
image = pipe(prompt, generator=generator, num_inference_steps=10, output_type="np").images
plt.imshow(image[0])
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /var/folders/4z/qx7dcv2s1f13n9qd0cqkyjdc0000gn/T/ipykernel_38688/3169725130.py in <module>
# ----> 1 pipe = pipe.to("mps")
#       2
#       3 # Recommended if your computer has < 64 GB of RAM
#       4 pipe.enable_attention_slicing()
#       5
#
# /opt/homebrew/Caskroom/miniforge/base/envs/pytorch_env/lib/python3.8/site-packages/diffusers/pipeline_utils.py in to(self, torch_device)
#     268                         " `torch_dtype=torch.float16` argument, or use another device for inference."
#     269                     )
# --> 270                 module.to(torch_device)
#     271         return self
#     272
#
# /opt/homebrew/Caskroom/miniforge/base/envs/pytorch_env/lib/python3.8/site-packages/transformers/modeling_utils.py in to(self, *args, **kwargs)
#    1894             )
#    1895         else:
# ...

# %%
#fix seed
generator = torch.Generator("cpu").manual_seed(1024)

prompt = "sailing ship in storm by Rembrandt"
image = pipe(prompt, generator=generator, num_inference_steps=25, output_type="np").images
plt.imshow(image[0])
# Out:
#   0%|          | 0/25 [00:00<?, ?it/s]

# %%
#fix seed
generator = torch.Generator("cpu").manual_seed(1024)

prompt = "sailing ship in storm by Rembrandt"
image = pipe(prompt, generator=generator, num_inference_steps=50, output_type="np").images
plt.imshow(image[0])
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
